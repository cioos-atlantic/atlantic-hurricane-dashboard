# %%
from tropycal import realtime
realtime_obj = realtime.Realtime(jtwc=True, jtwc_source = 'ucar')
realtime_obj
realtime_obj.list_active_storms(basin='all')
realtime_obj.plot_summary(domain={'w':-100,'e':-10,'s':4,'n':60})
# Out:
# --> Starting to read in current storm data
# --> Completed reading in current storm data (9.46 seconds)
# <GeoAxesSubplot:title={'left':'Summary & NHC 5-Day Formation Outlook','right':'Valid: 14 UTC 28 Mar 2023'}>

# %%
realtime_obj.plot_summary()
# Out:
# <GeoAxesSubplot:title={'left':'Summary & NHC 5-Day Formation Outlook','right':'Valid: 14 UTC 28 Mar 2023'}>

# %%
realtime_obj
# Out:
# <tropycal.realtime.Realtime>
# Dataset Summary:
#     Numbers of active storms: 1
#     Time Updated: 1117 UTC 28 March 2023
#
# Active Storms:
#
# Active Invests:
#     SH962023
