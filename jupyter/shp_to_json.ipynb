# %%
import shapefile
import json
from pathlib import Path
import re

source_dir = "../../data_exploration/eccc/dd.weather.gc.ca/trajectoires/hurricane/shapefile/"
source_search_pattern = "**/*.shp"

destination_dir = "./data/forecasts/eccc"

filename_parser = re.compile(r'(?P<date>\d+)_(?P<time>\d+)Z_(?P<storm>\w+)\.(?P<type>\w+).*')

# %%
def shp_to_json(shp_file:Path):
    shp_file_obj = shapefile.Reader(shp_file.as_posix())
    json_data = shp_file_obj.__geo_interface__

    return(json_data)

# %%
storm_index = {}

for shp_file_path in Path(source_dir).glob(source_search_pattern):
    shp_file = Path(shp_file_path)

    (storm_date, storm_time, storm_name, data_type) = filename_parser.match(shp_file.name).groupdict().values()

    storm_year = storm_date[0:4]

    print(f"Filename: {shp_file.name} Parts: {storm_date} {storm_time} {storm_name} {data_type}")

    json_data = shp_to_json(shp_file=shp_file)

    output_path = f"{storm_name}/{storm_date}/{storm_time}"

    final_output_path = Path(f"{destination_dir}/{output_path}/{data_type}.json")
    print(f"Output path: {final_output_path}")
    
    if storm_name not in storm_index:
        storm_index[storm_name] = []

    storm_index[storm_name].append(
        {
        "date":storm_date,
        "time":storm_time,
        "type":data_type,
        "path":final_output_path.as_posix()
        }
    )

    Path.mkdir(final_output_path.parent, parents=True, exist_ok=True)
    json.dump(json_data, open(final_output_path, mode="w+", encoding="UTF-8"))
# Out:
# Filename: 20220909_0600Z_EARL.err.shp Parts: 20220909 0600 EARL err
# Output path: data\forecasts\eccc\EARL\20220909\0600\err.json
# Filename: 20220909_0600Z_EARL.lin.shp Parts: 20220909 0600 EARL lin
# Output path: data\forecasts\eccc\EARL\20220909\0600\lin.json
# Filename: 20220909_0600Z_EARL.pts.shp Parts: 20220909 0600 EARL pts
# Output path: data\forecasts\eccc\EARL\20220909\0600\pts.json
# Filename: 20220909_0600Z_EARL.rad.shp Parts: 20220909 0600 EARL rad
# Output path: data\forecasts\eccc\EARL\20220909\0600\rad.json
# Filename: 20220909_1200Z_EARL.err.shp Parts: 20220909 1200 EARL err
# Output path: data\forecasts\eccc\EARL\20220909\1200\err.json
# Filename: 20220909_1200Z_EARL.lin.shp Parts: 20220909 1200 EARL lin
# Output path: data\forecasts\eccc\EARL\20220909\1200\lin.json
# Filename: 20220909_1200Z_EARL.pts.shp Parts: 20220909 1200 EARL pts
# Output path: data\forecasts\eccc\EARL\20220909\1200\pts.json
# Filename: 20220909_1200Z_EARL.rad.shp Parts: 20220909 1200 EARL rad
# Output path: data\forecasts\eccc\EARL\20220909\1200\rad.json
# Filename: 20220909_1800Z_EARL.err.shp Parts: 20220909 1800 EARL err
# Output path: data\forecasts\eccc\EARL\20220909\1800\err.json
# Filename: 20220909_1800Z_EARL.lin.shp Parts: 20220909 1800 EARL lin
# Output path: data\forecasts\eccc\EARL\20220909\1800\lin.json
# Filename: 20220909_1800Z_EARL.pts.shp Parts: 20220909 1800 EARL pts
# Output path: data\forecasts\eccc\EARL\20220909\1800\pts.json
# Filename: 20220909_1800Z_EARL.rad.shp Parts: 20220909 1800 EARL rad
# Output path: data\forecasts\eccc\EARL\20220909\1800\rad.json
# Filename: 20220910_0000Z_EARL.err.shp Parts: 20220910 0000 EARL err
# Output path: data\forecasts\eccc\EARL\20220910\0000\err.json
# Filename: 20220910_0000Z_EARL.lin.shp Parts: 20220910 0000 EARL lin
# Output path: data\forecasts\eccc\EARL\20220910\0000\lin.json
# Filename: 20220910_0000Z_EARL.pts.shp Parts: 20220910 0000 EARL pts
# Output path: data\forecasts\eccc\EARL\20220910\0000\pts.json
# Filename: 20220910_0000Z_EARL.rad.shp Parts: 20220910 0000 EARL rad
# Output path: data\forecasts\eccc\EARL\20220910\0000\rad.json
# Filename: 20220910_0600Z_EARL.err.shp Parts: 20220910 0600 EARL err
# Output path: data\forecasts\eccc\EARL\20220910\0600\err.json
# Filename: 20220910_0600Z_EARL.lin.shp Parts: 20220910 0600 EARL lin
# Output path: data\forecasts\eccc\EARL\20220910\0600\lin.json
# Filename: 20220910_0600Z_EARL.pts.shp Parts: 20220910 0600 EARL pts
# Output path: data\forecasts\eccc\EARL\20220910\0600\pts.json
# Filename: 20220910_0600Z_EARL.rad.shp Parts: 20220910 0600 EARL rad
# Output path: data\forecasts\eccc\EARL\20220910\0600\rad.json
# Filename: 20220910_1200Z_EARL.err.shp Parts: 20220910 1200 EARL err
# Output path: data\forecasts\eccc\EARL\20220910\1200\err.json
# Filename: 20220910_1200Z_EARL.lin.shp Parts: 20220910 1200 EARL lin
# Output path: data\forecasts\eccc\EARL\20220910\1200\lin.json
# Filename: 20220910_1200Z_EARL.pts.shp Parts: 20220910 1200 EARL pts
# Output path: data\forecasts\eccc\EARL\20220910\1200\pts.json
# Filename: 20220910_1200Z_EARL.rad.shp Parts: 20220910 1200 EARL rad
# Output path: data\forecasts\eccc\EARL\20220910\1200\rad.json
# Filename: 20220910_1800Z_EARL.err.shp Parts: 20220910 1800 EARL err
# Output path: data\forecasts\eccc\EARL\20220910\1800\err.json
# Filename: 20220910_1800Z_EARL.lin.shp Parts: 20220910 1800 EARL lin
# Output path: data\forecasts\eccc\EARL\20220910\1800\lin.json
# Filename: 20220910_1800Z_EARL.pts.shp Parts: 20220910 1800 EARL pts
# Output path: data\forecasts\eccc\EARL\20220910\1800\pts.json
# Filename: 20220910_1800Z_EARL.rad.shp Parts: 20220910 1800 EARL rad
# Output path: data\forecasts\eccc\EARL\20220910\1800\rad.json
# Filename: 20220911_0000Z_EARL.err.shp Parts: 20220911 0000 EARL err
# Output path: data\forecasts\eccc\EARL\20220911\0000\err.json
# Filename: 20220911_0000Z_EARL.lin.shp Parts: 20220911 0000 EARL lin
# Output path: data\forecasts\eccc\EARL\20220911\0000\lin.json
# Filename: 20220911_0000Z_EARL.pts.shp Parts: 20220911 0000 EARL pts
# Output path: data\forecasts\eccc\EARL\20220911\0000\pts.json
# Filename: 20220911_0000Z_EARL.rad.shp Parts: 20220911 0000 EARL rad
# Output path: data\forecasts\eccc\EARL\20220911\0000\rad.json
# Filename: 20220911_0600Z_EARL.err.shp Parts: 20220911 0600 EARL err
# Output path: data\forecasts\eccc\EARL\20220911\0600\err.json
# Filename: 20220911_0600Z_EARL.lin.shp Parts: 20220911 0600 EARL lin
# Output path: data\forecasts\eccc\EARL\20220911\0600\lin.json
# Filename: 20220911_0600Z_EARL.pts.shp Parts: 20220911 0600 EARL pts
# Output path: data\forecasts\eccc\EARL\20220911\0600\pts.json
# Filename: 20220911_0600Z_EARL.rad.shp Parts: 20220911 0600 EARL rad
# Output path: data\forecasts\eccc\EARL\20220911\0600\rad.json
# Filename: 20220921_1200Z_FIONA.err.shp Parts: 20220921 1200 FIONA err
# Output path: data\forecasts\eccc\FIONA\20220921\1200\err.json
# Filename: 20220921_1200Z_FIONA.lin.shp Parts: 20220921 1200 FIONA lin
# Output path: data\forecasts\eccc\FIONA\20220921\1200\lin.json
# Filename: 20220921_1200Z_FIONA.pts.shp Parts: 20220921 1200 FIONA pts
# Output path: data\forecasts\eccc\FIONA\20220921\1200\pts.json
# Filename: 20220921_1200Z_FIONA.rad.shp Parts: 20220921 1200 FIONA rad
# Output path: data\forecasts\eccc\FIONA\20220921\1200\rad.json
# Filename: 20220921_1800Z_FIONA.err.shp Parts: 20220921 1800 FIONA err
# Output path: data\forecasts\eccc\FIONA\20220921\1800\err.json
# Filename: 20220921_1800Z_FIONA.lin.shp Parts: 20220921 1800 FIONA lin
# Output path: data\forecasts\eccc\FIONA\20220921\1800\lin.json
# Filename: 20220921_1800Z_FIONA.pts.shp Parts: 20220921 1800 FIONA pts
# Output path: data\forecasts\eccc\FIONA\20220921\1800\pts.json
# Filename: 20220921_1800Z_FIONA.rad.shp Parts: 20220921 1800 FIONA rad
# Output path: data\forecasts\eccc\FIONA\20220921\1800\rad.json
# Filename: 20220922_0000Z_FIONA.err.shp Parts: 20220922 0000 FIONA err
# Output path: data\forecasts\eccc\FIONA\20220922\0000\err.json
# Filename: 20220922_0000Z_FIONA.lin.shp Parts: 20220922 0000 FIONA lin
# Output path: data\forecasts\eccc\FIONA\20220922\0000\lin.json
# Filename: 20220922_0000Z_FIONA.pts.shp Parts: 20220922 0000 FIONA pts
# Output path: data\forecasts\eccc\FIONA\20220922\0000\pts.json
# Filename: 20220922_0000Z_FIONA.rad.shp Parts: 20220922 0000 FIONA rad
# Output path: data\forecasts\eccc\FIONA\20220922\0000\rad.json
# Filename: 20220922_1200Z_FIONA.err.shp Parts: 20220922 1200 FIONA err
# Output path: data\forecasts\eccc\FIONA\20220922\1200\err.json
# Filename: 20220922_1200Z_FIONA.lin.shp Parts: 20220922 1200 FIONA lin
# Output path: data\forecasts\eccc\FIONA\20220922\1200\lin.json
# Filename: 20220922_1200Z_FIONA.pts.shp Parts: 20220922 1200 FIONA pts
# Output path: data\forecasts\eccc\FIONA\20220922\1200\pts.json
# Filename: 20220922_1200Z_FIONA.rad.shp Parts: 20220922 1200 FIONA rad
# Output path: data\forecasts\eccc\FIONA\20220922\1200\rad.json
# Filename: 20220922_1800Z_FIONA.err.shp Parts: 20220922 1800 FIONA err
# Output path: data\forecasts\eccc\FIONA\20220922\1800\err.json
# Filename: 20220922_1800Z_FIONA.lin.shp Parts: 20220922 1800 FIONA lin
# Output path: data\forecasts\eccc\FIONA\20220922\1800\lin.json
# Filename: 20220922_1800Z_FIONA.pts.shp Parts: 20220922 1800 FIONA pts
# Output path: data\forecasts\eccc\FIONA\20220922\1800\pts.json
# Filename: 20220922_1800Z_FIONA.rad.shp Parts: 20220922 1800 FIONA rad
# Output path: data\forecasts\eccc\FIONA\20220922\1800\rad.json
# Filename: 20220923_0000Z_FIONA.err.shp Parts: 20220923 0000 FIONA err
# Output path: data\forecasts\eccc\FIONA\20220923\0000\err.json
# Filename: 20220923_0000Z_FIONA.lin.shp Parts: 20220923 0000 FIONA lin
# Output path: data\forecasts\eccc\FIONA\20220923\0000\lin.json
# Filename: 20220923_0000Z_FIONA.pts.shp Parts: 20220923 0000 FIONA pts
# Output path: data\forecasts\eccc\FIONA\20220923\0000\pts.json
# Filename: 20220923_0000Z_FIONA.rad.shp Parts: 20220923 0000 FIONA rad
# Output path: data\forecasts\eccc\FIONA\20220923\0000\rad.json
# Filename: 20220923_0600Z_FIONA.err.shp Parts: 20220923 0600 FIONA err
# Output path: data\forecasts\eccc\FIONA\20220923\0600\err.json
# Filename: 20220923_0600Z_FIONA.lin.shp Parts: 20220923 0600 FIONA lin
# Output path: data\forecasts\eccc\FIONA\20220923\0600\lin.json
# Filename: 20220923_0600Z_FIONA.pts.shp Parts: 20220923 0600 FIONA pts
# Output path: data\forecasts\eccc\FIONA\20220923\0600\pts.json
# Filename: 20220923_0600Z_FIONA.rad.shp Parts: 20220923 0600 FIONA rad
# Output path: data\forecasts\eccc\FIONA\20220923\0600\rad.json
# Filename: 20220923_1200Z_FIONA.err.shp Parts: 20220923 1200 FIONA err
# Output path: data\forecasts\eccc\FIONA\20220923\1200\err.json
# Filename: 20220923_1200Z_FIONA.lin.shp Parts: 20220923 1200 FIONA lin
# Output path: data\forecasts\eccc\FIONA\20220923\1200\lin.json
# Filename: 20220923_1200Z_FIONA.pts.shp Parts: 20220923 1200 FIONA pts
# Output path: data\forecasts\eccc\FIONA\20220923\1200\pts.json
# Filename: 20220923_1200Z_FIONA.rad.shp Parts: 20220923 1200 FIONA rad
# Output path: data\forecasts\eccc\FIONA\20220923\1200\rad.json
# Filename: 20220923_1800Z_FIONA.err.shp Parts: 20220923 1800 FIONA err
# Output path: data\forecasts\eccc\FIONA\20220923\1800\err.json
# Filename: 20220923_1800Z_FIONA.lin.shp Parts: 20220923 1800 FIONA lin
# Output path: data\forecasts\eccc\FIONA\20220923\1800\lin.json
# Filename: 20220923_1800Z_FIONA.pts.shp Parts: 20220923 1800 FIONA pts
# Output path: data\forecasts\eccc\FIONA\20220923\1800\pts.json
# Filename: 20220923_1800Z_FIONA.rad.shp Parts: 20220923 1800 FIONA rad
# Output path: data\forecasts\eccc\FIONA\20220923\1800\rad.json
# Filename: 20220924_0000Z_FIONA.err.shp Parts: 20220924 0000 FIONA err
# Output path: data\forecasts\eccc\FIONA\20220924\0000\err.json
# Filename: 20220924_0000Z_FIONA.lin.shp Parts: 20220924 0000 FIONA lin
# Output path: data\forecasts\eccc\FIONA\20220924\0000\lin.json
# Filename: 20220924_0000Z_FIONA.pts.shp Parts: 20220924 0000 FIONA pts
# Output path: data\forecasts\eccc\FIONA\20220924\0000\pts.json
# Filename: 20220924_0000Z_FIONA.rad.shp Parts: 20220924 0000 FIONA rad
# Output path: data\forecasts\eccc\FIONA\20220924\0000\rad.json
# Filename: 20220924_0600Z_FIONA.err.shp Parts: 20220924 0600 FIONA err
# Output path: data\forecasts\eccc\FIONA\20220924\0600\err.json
# Filename: 20220924_0600Z_FIONA.lin.shp Parts: 20220924 0600 FIONA lin
# Output path: data\forecasts\eccc\FIONA\20220924\0600\lin.json
# Filename: 20220924_0600Z_FIONA.pts.shp Parts: 20220924 0600 FIONA pts
# Output path: data\forecasts\eccc\FIONA\20220924\0600\pts.json
# Filename: 20220924_0600Z_FIONA.rad.shp Parts: 20220924 0600 FIONA rad
# Output path: data\forecasts\eccc\FIONA\20220924\0600\rad.json
# Filename: 20220924_1200Z_FIONA.err.shp Parts: 20220924 1200 FIONA err
# Output path: data\forecasts\eccc\FIONA\20220924\1200\err.json
# Filename: 20220924_1200Z_FIONA.lin.shp Parts: 20220924 1200 FIONA lin
# Output path: data\forecasts\eccc\FIONA\20220924\1200\lin.json
# Filename: 20220924_1200Z_FIONA.pts.shp Parts: 20220924 1200 FIONA pts
# Output path: data\forecasts\eccc\FIONA\20220924\1200\pts.json
# Filename: 20220924_1200Z_FIONA.rad.shp Parts: 20220924 1200 FIONA rad
# Output path: data\forecasts\eccc\FIONA\20220924\1200\rad.json
# Filename: 20220924_1800Z_FIONA.err.shp Parts: 20220924 1800 FIONA err
# Output path: data\forecasts\eccc\FIONA\20220924\1800\err.json
# Filename: 20220924_1800Z_FIONA.lin.shp Parts: 20220924 1800 FIONA lin
# Output path: data\forecasts\eccc\FIONA\20220924\1800\lin.json
# Filename: 20220924_1800Z_FIONA.pts.shp Parts: 20220924 1800 FIONA pts
# Output path: data\forecasts\eccc\FIONA\20220924\1800\pts.json
# Filename: 20220924_1800Z_FIONA.rad.shp Parts: 20220924 1800 FIONA rad
# Output path: data\forecasts\eccc\FIONA\20220924\1800\rad.json
# Filename: 20220925_0000Z_FIONA.err.shp Parts: 20220925 0000 FIONA err
# Output path: data\forecasts\eccc\FIONA\20220925\0000\err.json
# Filename: 20220925_0000Z_FIONA.lin.shp Parts: 20220925 0000 FIONA lin
# Output path: data\forecasts\eccc\FIONA\20220925\0000\lin.json
# Filename: 20220925_0000Z_FIONA.pts.shp Parts: 20220925 0000 FIONA pts
# Output path: data\forecasts\eccc\FIONA\20220925\0000\pts.json
# Filename: 20220925_0000Z_FIONA.rad.shp Parts: 20220925 0000 FIONA rad
# Output path: data\forecasts\eccc\FIONA\20220925\0000\rad.json
# Filename: 20220925_0600Z_FIONA.err.shp Parts: 20220925 0600 FIONA err
# Output path: data\forecasts\eccc\FIONA\20220925\0600\err.json
# Filename: 20220925_0600Z_FIONA.lin.shp Parts: 20220925 0600 FIONA lin
# Output path: data\forecasts\eccc\FIONA\20220925\0600\lin.json
# Filename: 20220925_0600Z_FIONA.pts.shp Parts: 20220925 0600 FIONA pts
# Output path: data\forecasts\eccc\FIONA\20220925\0600\pts.json
# Filename: 20220925_0600Z_FIONA.rad.shp Parts: 20220925 0600 FIONA rad
# Output path: data\forecasts\eccc\FIONA\20220925\0600\rad.json
# Filename: 20220925_1200Z_FIONA.err.shp Parts: 20220925 1200 FIONA err
# Output path: data\forecasts\eccc\FIONA\20220925\1200\err.json
# Filename: 20220925_1200Z_FIONA.lin.shp Parts: 20220925 1200 FIONA lin
# Output path: data\forecasts\eccc\FIONA\20220925\1200\lin.json
# Filename: 20220925_1200Z_FIONA.pts.shp Parts: 20220925 1200 FIONA pts
# Output path: data\forecasts\eccc\FIONA\20220925\1200\pts.json
# Filename: 20220925_1200Z_FIONA.rad.shp Parts: 20220925 1200 FIONA rad
# Output path: data\forecasts\eccc\FIONA\20220925\1200\rad.json

# %%
for storm in storm_index:
    output_path = Path(f"{destination_dir}/{storm}/index.json").as_posix()
    print(output_path)
    print(storm_index[storm])
    json.dump(storm_index[storm], open(output_path, mode="w+", encoding="UTF-8"))
# Out:
# data/forecasts/eccc/EARL/index.json
# [{'date': '20220909', 'time': '0600', 'type': 'err', 'path': 'data/forecasts/eccc/EARL/20220909/0600/err.json'}, {'date': '20220909', 'time': '0600', 'type': 'lin', 'path': 'data/forecasts/eccc/EARL/20220909/0600/lin.json'}, {'date': '20220909', 'time': '0600', 'type': 'pts', 'path': 'data/forecasts/eccc/EARL/20220909/0600/pts.json'}, {'date': '20220909', 'time': '0600', 'type': 'rad', 'path': 'data/forecasts/eccc/EARL/20220909/0600/rad.json'}, {'date': '20220909', 'time': '1200', 'type': 'err', 'path': 'data/forecasts/eccc/EARL/20220909/1200/err.json'}, {'date': '20220909', 'time': '1200', 'type': 'lin', 'path': 'data/forecasts/eccc/EARL/20220909/1200/lin.json'}, {'date': '20220909', 'time': '1200', 'type': 'pts', 'path': 'data/forecasts/eccc/EARL/20220909/1200/pts.json'}, {'date': '20220909', 'time': '1200', 'type': 'rad', 'path': 'data/forecasts/eccc/EARL/20220909/1200/rad.json'}, {'date': '20220909', 'time': '1800', 'type': 'err', 'path': 'data/forecasts/eccc/EARL/20220909/1800/err.json'}, {'date': '20220909', 'time': '1800', 'type': 'lin', 'path': 'data/forecasts/eccc/EARL/20220909/1800/lin.json'}, {'date': '20220909', 'time': '1800', 'type': 'pts', 'path': 'data/forecasts/eccc/EARL/20220909/1800/pts.json'}, {'date': '20220909', 'time': '1800', 'type': 'rad', 'path': 'data/forecasts/eccc/EARL/20220909/1800/rad.json'}, {'date': '20220910', 'time': '0000', 'type': 'err', 'path': 'data/forecasts/eccc/EARL/20220910/0000/err.json'}, {'date': '20220910', 'time': '0000', 'type': 'lin', 'path': 'data/forecasts/eccc/EARL/20220910/0000/lin.json'}, {'date': '20220910', 'time': '0000', 'type': 'pts', 'path': 'data/forecasts/eccc/EARL/20220910/0000/pts.json'}, {'date': '20220910', 'time': '0000', 'type': 'rad', 'path': 'data/forecasts/eccc/EARL/20220910/0000/rad.json'}, {'date': '20220910', 'time': '0600', 'type': 'err', 'path': 'data/forecasts/eccc/EARL/20220910/0600/err.json'}, {'date': '20220910', 'time': '0600', 'type': 'lin', 'path': 'data/forecasts/eccc/EARL/20220910/0600/lin.json'}, {'date': '20220910', 'time': '0600', 'type': 'pts', 'path': 'data/forecasts/eccc/EARL/20220910/0600/pts.json'}, {'date': '20220910', 'time': '0600', 'type': 'rad', 'path': 'data/forecasts/eccc/EARL/20220910/0600/rad.json'}, {'date': '20220910', 'time': '1200', 'type': 'err', 'path': 'data/forecasts/eccc/EARL/20220910/1200/err.json'}, {'date': '20220910', 'time': '1200', 'type': 'lin', 'path': 'data/forecasts/eccc/EARL/20220910/1200/lin.json'}, {'date': '20220910', 'time': '1200', 'type': 'pts', 'path': 'data/forecasts/eccc/EARL/20220910/1200/pts.json'}, {'date': '20220910', 'time': '1200', 'type': 'rad', 'path': 'data/forecasts/eccc/EARL/20220910/1200/rad.json'}, {'date': '20220910', 'time': '1800', 'type': 'err', 'path': 'data/forecasts/eccc/EARL/20220910/1800/err.json'}, {'date': '20220910', 'time': '1800', 'type': 'lin', 'path': 'data/forecasts/eccc/EARL/20220910/1800/lin.json'}, {'date': '20220910', 'time': '1800', 'type': 'pts', 'path': 'data/forecasts/eccc/EARL/20220910/1800/pts.json'}, {'date': '20220910', 'time': '1800', 'type': 'rad', 'path': 'data/forecasts/eccc/EARL/20220910/1800/rad.json'}, {'date': '20220911', 'time': '0000', 'type': 'err', 'path': 'data/forecasts/eccc/EARL/20220911/0000/err.json'}, {'date': '20220911', 'time': '0000', 'type': 'lin', 'path': 'data/forecasts/eccc/EARL/20220911/0000/lin.json'}, {'date': '20220911', 'time': '0000', 'type': 'pts', 'path': 'data/forecasts/eccc/EARL/20220911/0000/pts.json'}, {'date': '20220911', 'time': '0000', 'type': 'rad', 'path': 'data/forecasts/eccc/EARL/20220911/0000/rad.json'}, {'date': '20220911', 'time': '0600', 'type': 'err', 'path': 'data/forecasts/eccc/EARL/20220911/0600/err.json'}, {'date': '20220911', 'time': '0600', 'type': 'lin', 'path': 'data/forecasts/eccc/EARL/20220911/0600/lin.json'}, {'date': '20220911', 'time': '0600', 'type': 'pts', 'path': 'data/forecasts/eccc/EARL/20220911/0600/pts.json'}, {'date': '20220911', 'time': '0600', 'type': 'rad', 'path': 'data/forecasts/ecc ...
# data/forecasts/eccc/FIONA/index.json
# [{'date': '20220921', 'time': '1200', 'type': 'err', 'path': 'data/forecasts/eccc/FIONA/20220921/1200/err.json'}, {'date': '20220921', 'time': '1200', 'type': 'lin', 'path': 'data/forecasts/eccc/FIONA/20220921/1200/lin.json'}, {'date': '20220921', 'time': '1200', 'type': 'pts', 'path': 'data/forecasts/eccc/FIONA/20220921/1200/pts.json'}, {'date': '20220921', 'time': '1200', 'type': 'rad', 'path': 'data/forecasts/eccc/FIONA/20220921/1200/rad.json'}, {'date': '20220921', 'time': '1800', 'type': 'err', 'path': 'data/forecasts/eccc/FIONA/20220921/1800/err.json'}, {'date': '20220921', 'time': '1800', 'type': 'lin', 'path': 'data/forecasts/eccc/FIONA/20220921/1800/lin.json'}, {'date': '20220921', 'time': '1800', 'type': 'pts', 'path': 'data/forecasts/eccc/FIONA/20220921/1800/pts.json'}, {'date': '20220921', 'time': '1800', 'type': 'rad', 'path': 'data/forecasts/eccc/FIONA/20220921/1800/rad.json'}, {'date': '20220922', 'time': '0000', 'type': 'err', 'path': 'data/forecasts/eccc/FIONA/20220922/0000/err.json'}, {'date': '20220922', 'time': '0000', 'type': 'lin', 'path': 'data/forecasts/eccc/FIONA/20220922/0000/lin.json'}, {'date': '20220922', 'time': '0000', 'type': 'pts', 'path': 'data/forecasts/eccc/FIONA/20220922/0000/pts.json'}, {'date': '20220922', 'time': '0000', 'type': 'rad', 'path': 'data/forecasts/eccc/FIONA/20220922/0000/rad.json'}, {'date': '20220922', 'time': '1200', 'type': 'err', 'path': 'data/forecasts/eccc/FIONA/20220922/1200/err.json'}, {'date': '20220922', 'time': '1200', 'type': 'lin', 'path': 'data/forecasts/eccc/FIONA/20220922/1200/lin.json'}, {'date': '20220922', 'time': '1200', 'type': 'pts', 'path': 'data/forecasts/eccc/FIONA/20220922/1200/pts.json'}, {'date': '20220922', 'time': '1200', 'type': 'rad', 'path': 'data/forecasts/eccc/FIONA/20220922/1200/rad.json'}, {'date': '20220922', 'time': '1800', 'type': 'err', 'path': 'data/forecasts/eccc/FIONA/20220922/1800/err.json'}, {'date': '20220922', 'time': '1800', 'type': 'lin', 'path': 'data/forecasts/eccc/FIONA/20220922/1800/lin.json'}, {'date': '20220922', 'time': '1800', 'type': 'pts', 'path': 'data/forecasts/eccc/FIONA/20220922/1800/pts.json'}, {'date': '20220922', 'time': '1800', 'type': 'rad', 'path': 'data/forecasts/eccc/FIONA/20220922/1800/rad.json'}, {'date': '20220923', 'time': '0000', 'type': 'err', 'path': 'data/forecasts/eccc/FIONA/20220923/0000/err.json'}, {'date': '20220923', 'time': '0000', 'type': 'lin', 'path': 'data/forecasts/eccc/FIONA/20220923/0000/lin.json'}, {'date': '20220923', 'time': '0000', 'type': 'pts', 'path': 'data/forecasts/eccc/FIONA/20220923/0000/pts.json'}, {'date': '20220923', 'time': '0000', 'type': 'rad', 'path': 'data/forecasts/eccc/FIONA/20220923/0000/rad.json'}, {'date': '20220923', 'time': '0600', 'type': 'err', 'path': 'data/forecasts/eccc/FIONA/20220923/0600/err.json'}, {'date': '20220923', 'time': '0600', 'type': 'lin', 'path': 'data/forecasts/eccc/FIONA/20220923/0600/lin.json'}, {'date': '20220923', 'time': '0600', 'type': 'pts', 'path': 'data/forecasts/eccc/FIONA/20220923/0600/pts.json'}, {'date': '20220923', 'time': '0600', 'type': 'rad', 'path': 'data/forecasts/eccc/FIONA/20220923/0600/rad.json'}, {'date': '20220923', 'time': '1200', 'type': 'err', 'path': 'data/forecasts/eccc/FIONA/20220923/1200/err.json'}, {'date': '20220923', 'time': '1200', 'type': 'lin', 'path': 'data/forecasts/eccc/FIONA/20220923/1200/lin.json'}, {'date': '20220923', 'time': '1200', 'type': 'pts', 'path': 'data/forecasts/eccc/FIONA/20220923/1200/pts.json'}, {'date': '20220923', 'time': '1200', 'type': 'rad', 'path': 'data/forecasts/eccc/FIONA/20220923/1200/rad.json'}, {'date': '20220923', 'time': '1800', 'type': 'err', 'path': 'data/forecasts/eccc/FIONA/20220923/1800/err.json'}, {'date': '20220923', 'time': '1800', 'type': 'lin', 'path': 'data/forecasts/eccc/FIONA/20220923/1800/lin.json'}, {'date': '20220923', 'time': '1800', 'type': 'pts', 'path': 'data/forecasts/eccc/FIONA/20220923/1800/pts.json'}, {'date': '20220923', 'time': '1800', 'type': ...
