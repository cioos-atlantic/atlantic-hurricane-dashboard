# %%
import os

station_data_path = "../station-data/"
storm_id = "2022_fiona"

if os.path.exists(station_data_path + storm_id):
    print("path exists")
else:
    print("Path does not exist")
# Out:
# path exists

# %%
import pandas as pd
import os

# Search for a specific variable,
#   ideally pass in from a standard list to avoid vocab issues
# If left blank, will just grab the whole dataset
variable = 'wind_speed'

# This section will likely change depending on how the data will be stored
# Current format is writing the datasets from 'search_by_standard_name' notebook to csv
#   in the station-data folder
storm_station_folder = station_data_path + storm_id
for station in os.listdir(storm_station_folder):
    station_file = os.path.join(storm_station_folder, station)
    if os.path.isfile(station_file):
        print(station_file)
        df = pd.read_csv(station_file, sep='\t')

        # This section can be reused with minor adjustments
        if(variable==''):
            print(df.head(3))
        else:
            # Get a list of 'essential' variables (lat, lon, time) (may only need time)
            base_cols = '\(time\||\(latitude\||\(longitude\|'
            # Starting the field with '(' and ending with '|' ensures we are matching the exact standard name
            df2 = df.filter(regex=base_cols + '|\(' + variable + '\|')
            if(df2.columns.size > 3):
                print(df2.head(3))
            else:
                print('Variable does not exist for station')
# Out:
# ../station-data/2022_fiona/SMA_port_aux_basqes_wharf.csv
#    Unnamed: 0 time (time|UTC|Timestamp)  \
# 0           0      2022-09-20T00:01:03Z
# 1           1      2022-09-20T00:02:11Z
# 2           2      2022-09-20T00:03:19Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                   47.574533
# 1                                   47.574533
# 2                                   47.574533
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                    -59.139467
# 1                                    -59.139467
# 2                                    -59.139467
#
#    wind_spd_avg (wind_speed|m s-1|Wind Spd Avg)  \
# 0                                           1.4
# 1                                           1.8
# 2                                           1.8
#
#    wind_spd_max (wind_speed_of_gust|m s-1|Wind Spd Max)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    wind_dir_avg (wind_from_direction|degree|Wind From Direction)
# 0                                              235.9
# 1                                              249.9
# 2                                              252.7
# ../station-data/2022_fiona/force_meteorological_tower.csv
#    Unnamed: 0  time (time|UTC|Date)  \
# 0           0  2022-09-20T00:01:00Z
# 1           1  2022-09-20T00:16:03Z
# 2           2  2022-09-20T00:31:00Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                     45.3713
# 1                                     45.3713
# 2                                     45.3713
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                       -64.403
# 1                                       -64.403
# 2                                       -64.403
#
#    wind_speed_15min_max (wind_speed_of_gust|m/s|Wind Speed 15min Max)  \
# 0                                             4.3316
# 1                                             4.0376
# 2                                             3.8808
#
#    air_pressure (air_pressure|hPa|Air Pressure)  \
# 0                                      1016.458
# 1                                      1016.458
# 2                                      1016.458
#
#    air_temperature_1min_max (air_temperature|degree_Celsius|Air Temperature 1min Max)  \
# 0                                              12.61
# 1                                              12.64
# 2                                              12.34
#
#    wind_speed (wind_speed|m/s|Wind Speed)  \
# 0                                  2.3128
# 1                                  2.1168
# 2                                  2.0188
#
#    relative_humidity (relative_humidity|percent|Relative Humidity)  \
# 0                                           65.89831
# 1                                           66.57627
# 2                                           68.94915
#
#    wind_speed_15min_average (wind_speed|m/s|Wind Speed 15min Average)  \
# 0                                           2.816782
# 1                                           2.289141
# 2                                           2.332750
#
#    air_pressure_raw (air_pressure|hPa|Air Pressure Raw)  \
# 0                                           1014.658
# 1                                           1014.658
# 2                                           1014.658
#
#    wind_speed_2min_max (wind_speed_of_gust|m/s|Wind Speed 2min Max)  \
# 0                                              3.920
# 1                                              3.038
# 2                                              2.528
#
#    wind_from_direction (wind_from_direction|degree|Wind From Direction)  \
# 0                                           85.63322
# 1                                           94.22542
# 2                                           75.93390
#
#    wind_speed_15min_median (wind_speed|m/s|Wind Speed 15min Median)  \
# 0                                             2.7832
# 1                                             2.2932
# 2                                             2.2932
#
#    wind_from_direction_15min_average (wind_from_direction|degree|Wind From Direction 15min Average)  \
# 0                                          79.814704
# 1                                          81.595387
# 2                                          83.837715
#
#    air_temperature (air_temperature|degree_Celsius|Air Temperature)
# 0                                           12.61017
# 1                                           12.54237
# 2                                           12.33898
# ../station-data/2022_fiona/SMA_Fortune_Bay_Buoy.csv
#    Unnamed: 0 time (time|UTC|Timestamp)  \
# 0           0      2022-09-20T00:27:00Z
# 1           1      2022-09-20T00:57:00Z
# 2           2      2022-09-20T01:27:00Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                   47.260857
# 1                                   47.260857
# 2                                   47.260857
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                    -55.498453
# 1                                    -55.498453
# 2                                    -55.498453
#
#    wind_spd_avg (wind_speed|m s-1|Wind Spd Avg)  \
# 0                                           3.3
# 1                                           3.2
# 2                                           4.9
#
#    air_temp_avg (air_temperature|degree_C|Air Temp Avg)  \
# 0                                               12.6
# 1                                               12.8
# 2                                               13.1
#
#    air_pressure_avg (air_pressure|mbar|Air Pressure)  \
# 0                                             1014.3
# 1                                             1014.5
# 2                                             1014.6
#
#    wind_spd_max (wind_speed_of_gust|m s-1|Wind Spd Max)  \
# 0                                                3.8
# 1                                                4.4
# 2                                                6.3
#
#    air_humidity_avg (relative_humidity|1|Air Humidity Avg)  \
# 0                                              100.0
# 1                                              100.0
# 2                                              100.0
#
#    wave_period_max (sea_surface_wave_maximum_period|s|Sea Surface Wave Maximum Period)  \
# 0                                                3.4
# 1                                                3.7
# 2                                                4.2
#
#    wind_dir_avg (wind_from_direction|degree|Wind From Direction)  \
# 0                                                313
# 1                                                347
# 2                                                 12
#
#    wave_ht_max (sea_surface_wave_maximum_height|m|Wave Ht Max)  \
# 0                                                0.8
# 1                                                0.6
# 2                                                0.5
#
#    surface_temp_avg (sea_surface_temperature|degree_C|Surface Temp Avg)  \
# 0                                               13.2
# 1                                               13.1
# 2                                               13.0
#
#    wave_ht_sig (sea_surface_wave_significant_height|m|Wave Ht Sig)
# 0                                                0.4
# 1                                                0.4
# 2                                                0.3
# ../station-data/2022_fiona/SMA_halifax_fairview.csv
#    Unnamed: 0 time (time|UTC|Timestamp)  \
# 0           0      2022-09-20T00:10:00Z
# 1           1      2022-09-20T00:20:00Z
# 2           2      2022-09-20T00:30:00Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                   44.664167
# 1                                   44.664167
# 2                                   44.664167
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                    -63.627217
# 1                                    -63.627217
# 2                                    -63.627217
#
#    wind_spd_avg (wind_speed|m s-1|Wind Spd Avg)  \
# 0                                           0.5
# 1                                           0.8
# 2                                           0.7
#
#    wind_spd_max (wind_speed_of_gust|m s-1|Wind Spd Max)  \
# 0                                                1.0
# 1                                                1.3
# 2                                                1.3
#
#    air_temp_avg (air_temperature|degree_C|Air Temp Avg)  \
# 0                                               14.5
# 1                                               14.5
# 2                                               14.4
#
#    wind_dir_avg (wind_from_direction|degree|Wind From Direction)  \
# 0                                                4.0
# 1                                                9.2
# 2                                              345.9
#
#    air_humidity_avg (relative_humidity|1|Air Humidity Avg)  \
# 0                                               69.9
# 1                                               70.7
# 2                                               72.5
#
#    air_pressure_avg (air_pressure|mbar|Air Pressure)
# 0                                             1016.0
# 1                                             1016.0
# 2                                             1016.0
# ../station-data/2022_fiona/SMA_halifax_anemometer1.csv
#    Unnamed: 0 time (time|UTC|Timestamp)  \
# 0           0      2022-09-20T00:00:00Z
# 1           1      2022-09-20T00:10:00Z
# 2           2      2022-09-20T00:20:00Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                   44.633552
# 1                                   44.633552
# 2                                   44.633552
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                    -63.562363
# 1                                    -63.562363
# 2                                    -63.562363
#
#    wind_spd_avg (wind_speed|m s-1|Wind Spd Avg)  \
# 0                                           0.8
# 1                                           2.5
# 2                                           2.1
#
#    wind_spd_max (wind_speed_of_gust|m s-1|Wind Spd Max)  \
# 0                                                1.2
# 1                                                3.4
# 2                                                3.2
#
#    wind_dir_avg (wind_from_direction|degree|Wind From Direction)
# 0                                              273.3
# 1                                              347.1
# 2                                                2.1
# ../station-data/2022_fiona/SMA_halifax_pier9c.csv
#    Unnamed: 0 time (time|UTC|Timestamp)  \
# 0           0      2022-09-20T00:10:00Z
# 1           1      2022-09-20T00:20:00Z
# 2           2      2022-09-20T00:30:00Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                   44.674833
# 1                                   44.674833
# 2                                   44.674833
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                    -63.609667
# 1                                    -63.609667
# 2                                    -63.609667
#
#    wind_spd_avg (wind_speed|m s-1|Wind Spd Avg)  \
# 0                                           0.6
# 1                                           0.5
# 2                                           0.4
#
#    wind_spd_max (wind_speed_of_gust|m s-1|Wind Spd Max)  \
# 0                                                1.2
# 1                                                1.1
# 2                                                0.8
#
#    air_temp_avg (air_temperature|degree_C|Air Temp Avg)  \
# 0                                               14.9
# 1                                               15.0
# 2                                               14.5
#
#    wind_dir_avg (wind_from_direction|degree|Wind From Direction)  \
# 0                                               78.0
# 1                                               77.4
# 2                                              168.3
#
#    air_humidity_avg (relative_humidity|1|Air Humidity Avg)  \
# 0                                               65.7
# 1                                               69.2
# 2                                               72.7
#
#    air_pressure_avg (air_pressure|mbar|Air Pressure)
# 0                                             1017.0
# 1                                             1017.0
# 2                                             1017.0
# ../station-data/2022_fiona/SMA_Holyrood_Buoy2.csv
#    Unnamed: 0 time (time|UTC|Timestamp)  \
# 0           0      2022-09-20T00:55:00Z
# 1           1      2022-09-20T01:55:00Z
# 2           2      2022-09-20T02:55:00Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                   47.461835
# 1                                   47.461835
# 2                                   47.461835
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                    -53.108107
# 1                                    -53.108107
# 2                                    -53.108107
#
#    wind_spd_avg (wind_speed|m s-1|Wind Spd Avg)  \
# 0                                           4.2
# 1                                           2.8
# 2                                           2.3
#
#    air_temp_avg (air_temperature|degree_C|Air Temp Avg)  \
# 0                                               12.0
# 1                                               11.1
# 2                                               10.5
#
#    air_pressure_avg (air_pressure|mbar|Air Pressure)  \
# 0                                             1008.4
# 1                                             1005.5
# 2                                             1003.1
#
#    wind_spd_max (wind_speed_of_gust|m s-1|Wind Spd Max)  \
# 0                                                4.9
# 1                                                3.8
# 2                                                3.0
#
#    air_humidity_avg (relative_humidity|1|Air Humidity Avg)  \
# 0                                              100.0
# 1                                              100.0
# 2                                              100.0
#
#    wave_period_max (sea_surface_wave_maximum_period|s|Sea Surface Wave Maximum Period)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    wind_dir_avg (wind_from_direction|degree|Wind From Direction)  \
# 0                                                132
# 1                                                147
# 2                                                173
#
#    wave_ht_max (sea_surface_wave_maximum_height|m|Wave Ht Max)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    surface_temp_avg (sea_surface_temperature|degree_C|Surface Temp Avg)  \
# 0                                               15.3
# 1                                               15.3
# 2                                               15.2
#
#    wave_ht_sig (sea_surface_wave_significant_height|m|Wave Ht Sig)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ../station-data/2022_fiona/SMA_holyrood_wharf.csv
#    Unnamed: 0 time (time|UTC|Timestamp)  \
# 0           0      2022-09-20T00:10:17Z
# 1           1      2022-09-20T00:31:20Z
# 2           2      2022-09-20T00:52:24Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                   47.388657
# 1                                   47.388657
# 2                                   47.388657
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                     -53.13495
# 1                                     -53.13495
# 2                                     -53.13495
#
#    wind_spd_avg (wind_speed|m s-1|Wind Spd Avg)  \
# 0                                           3.6
# 1                                           5.1
# 2                                           5.9
#
#    wind_spd_max (wind_speed_of_gust|m s-1|Wind Spd Max)  \
# 0                                                4.7
# 1                                                6.2
# 2                                                7.9
#
#    air_temp_avg (air_temperature|degree_C|Air Temp Avg)  \
# 0                                               13.4
# 1                                               13.1
# 2                                               12.4
#
#    wind_dir_avg (wind_from_direction|degree|Wind From Direction)  \
# 0                                              322.0
# 1                                              329.8
# 2                                              341.3
#
#    air_pressure_avg (air_pressure|mbar|Air Pressure)
# 0                                             1013.2
# 1                                             1013.5
# 2                                             1013.7
# ../station-data/2022_fiona/sma_negl_black_tickle_nlqu0003.csv
#    Unnamed: 0 time (time|UTC|Timestamp)  \
# 0           0      2022-09-20T00:52:00Z
# 1           1      2022-09-20T01:52:00Z
# 2           2      2022-09-20T02:52:00Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                    53.46371
# 1                                    53.46371
# 2                                    53.46371
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                     -55.77968
# 1                                     -55.77968
# 2                                     -55.77968
#
#    wind_spd_avg (wind_speed|m s-1|Wind Speed)  \
# 0                                    7.277778
# 1                                    5.555555
# 2                                    5.805555
#
#    air_temp_avg (air_temperature|degree_C|Air Temperature)  \
# 0                                                6.5
# 1                                                5.0
# 2                                                5.3
#
#    rel_humidity_max (relative_humidity|1|Relative Humidity (max))  \
# 0                                               79.0
# 1                                               82.0
# 2                                               82.0
#
#    wind_spd_max_dir (wind_from_direction|degree|Wind From Direction)  \
# 0                                              315.0
# 1                                              286.0
# 2                                              306.0
#
#    air_pressure_avg (air_pressure|mbar|Air Pressure)  \
# 0                                             1010.9
# 1                                             1011.0
# 2                                             1011.1
#
#    rel_humidity (relative_humidity|1|Relative Humidity)  \
# 0                                               78.0
# 1                                               82.0
# 2                                               79.0
#
#    rel_humidity_min (relative_humidity|1|Relative Humidity (min))  \
# 0                                               72.0
# 1                                               76.0
# 2                                               78.0
#
#    wind_spd_max (wind_speed_of_gust|m s-1|Wind Speed Of Gust)  \
# 0                                          13.111111
# 1                                           9.472222
# 2                                           9.944445
#
#    wind_dir_avg (wind_from_direction|degree|Wind From Direction)  \
# 0                                              303.0
# 1                                              285.0
# 2                                              291.0
#
#    air_temp_min (air_temperature|degree_C|Air Temperature (min))  \
# 0                                                6.1
# 1                                                5.0
# 2                                                4.9
#
#    air_temp_max (air_temperature|degree_C|Air Temperature (max))
# 0                                                6.6
# 1                                                6.5
# 2                                                5.6
# ../station-data/2022_fiona/sma_negl_north_west_river_nlqu0007.csv
#    Unnamed: 0 time (time|UTC|Timestamp)  \
# 0           0      2022-09-20T00:16:00Z
# 1           1      2022-09-20T01:16:00Z
# 2           2      2022-09-20T02:16:00Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                     53.5374
# 1                                     53.5374
# 2                                     53.5374
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                     -60.14918
# 1                                     -60.14918
# 2                                     -60.14918
#
#    wind_spd_avg (wind_speed|m s-1|Wind Speed)  \
# 0                                    1.000000
# 1                                    1.388889
# 2                                    2.111111
#
#    air_temp_avg (air_temperature|degree_C|Air Temperature)  \
# 0                                                4.6
# 1                                                3.5
# 2                                                6.0
#
#    rel_humidity_max (relative_humidity|1|Relative Humidity (max))  \
# 0                                               96.0
# 1                                               99.0
# 2                                              100.0
#
#    wind_spd_max_dir (wind_from_direction|degree|Wind From Direction)  \
# 0                                              229.0
# 1                                              286.0
# 2                                              283.0
#
#    air_pressure_avg (air_pressure|mbar|Air Pressure)  \
# 0                                             1011.1
# 1                                             1011.3
# 2                                             1011.6
#
#    rel_humidity (relative_humidity|1|Relative Humidity)  \
# 0                                               95.0
# 1                                               99.0
# 2                                               97.0
#
#    rel_humidity_min (relative_humidity|1|Relative Humidity (min))  \
# 0                                               85.0
# 1                                               91.0
# 2                                               94.0
#
#    wind_spd_max (wind_speed_of_gust|m s-1|Wind Speed Of Gust)  \
# 0                                           2.138889
# 1                                           3.138889
# 2                                           3.861111
#
#    wind_dir_avg (wind_from_direction|degree|Wind From Direction)  \
# 0                                              227.0
# 1                                              284.0
# 2                                              283.0
#
#    air_temp_min (air_temperature|degree_C|Air Temperature (min))  \
# 0                                                4.6
# 1                                                3.5
# 2                                                3.5
#
#    air_temp_max (air_temperature|degree_C|Air Temperature (max))
# 0                                                6.9
# 1                                                4.9
# 2                                                6.6
# ../station-data/2022_fiona/sma_negl_postville_nlqu0001.csv
#    Unnamed: 0 time (time|UTC|Timestamp)  \
# 0           0      2022-09-20T00:52:00Z
# 1           1      2022-09-20T01:52:00Z
# 2           2      2022-09-20T02:52:00Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                    54.90937
# 1                                    54.90937
# 2                                    54.90937
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                     -59.78048
# 1                                     -59.78048
# 2                                     -59.78048
#
#    wind_spd_avg (wind_speed|m s-1|Wind Speed)  \
# 0                                    2.583333
# 1                                    2.527778
# 2                                    2.638889
#
#    air_temp_avg (air_temperature|degree_C|Air Temperature)  \
# 0                                                5.6
# 1                                                6.1
# 2                                                5.0
#
#    rel_humidity_max (relative_humidity|1|Relative Humidity (max))  \
# 0                                               78.0
# 1                                               81.0
# 2                                               83.0
#
#    wind_spd_max_dir (wind_from_direction|degree|Wind From Direction)  \
# 0                                              214.0
# 1                                              220.0
# 2                                              218.0
#
#    air_pressure_avg (air_pressure|mbar|Air Pressure)  \
# 0                                             1008.5
# 1                                             1008.7
# 2                                             1008.9
#
#    rel_humidity (relative_humidity|1|Relative Humidity)  \
# 0                                               78.0
# 1                                               80.0
# 2                                               83.0
#
#    rel_humidity_min (relative_humidity|1|Relative Humidity (min))  \
# 0                                               57.0
# 1                                               76.0
# 2                                               79.0
#
#    wind_spd_max (wind_speed_of_gust|m s-1|Wind Speed Of Gust)  \
# 0                                           3.388889
# 1                                           3.694444
# 2                                           4.138889
#
#    wind_dir_avg (wind_from_direction|degree|Wind From Direction)  \
# 0                                              231.0
# 1                                              232.0
# 2                                              242.0
#
#    air_temp_min (air_temperature|degree_C|Air Temperature (min))  \
# 0                                                5.6
# 1                                                5.5
# 2                                                5.0
#
#    air_temp_max (air_temperature|degree_C|Air Temperature (max))
# 0                                                7.2
# 1                                                6.4
# 2                                                6.1
# ../station-data/2022_fiona/sma_negl_red_bay_nlqu0005.csv
#    Unnamed: 0 time (time|UTC|Timestamp)  \
# 0           0      2022-09-20T00:52:00Z
# 1           1      2022-09-20T01:52:00Z
# 2           2      2022-09-20T02:52:00Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                    51.74178
# 1                                    51.74178
# 2                                    51.74178
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                     -56.52707
# 1                                     -56.52707
# 2                                     -56.52707
#
#    wind_spd_avg (wind_speed|m s-1|Wind Speed)  \
# 0                                    5.111111
# 1                                    2.694444
# 2                                    1.305556
#
#    air_temp_avg (air_temperature|degree_C|Air Temperature)  \
# 0                                                4.9
# 1                                                4.0
# 2                                                3.3
#
#    rel_humidity_max (relative_humidity|1|Relative Humidity (max))  \
# 0                                               80.0
# 1                                               81.0
# 2                                               83.0
#
#    wind_spd_max_dir (wind_from_direction|degree|Wind From Direction)  \
# 0                                              319.0
# 1                                              323.0
# 2                                                3.0
#
#    air_pressure_avg (air_pressure|mbar|Air Pressure)  \
# 0                                              994.4
# 1                                              995.1
# 2                                              995.8
#
#    rel_humidity (relative_humidity|1|Relative Humidity)  \
# 0                                               79.0
# 1                                               81.0
# 2                                               82.0
#
#    rel_humidity_min (relative_humidity|1|Relative Humidity (min))  \
# 0                                               77.0
# 1                                               78.0
# 2                                               78.0
#
#    wind_spd_max (wind_speed_of_gust|m s-1|Wind Speed Of Gust)  \
# 0                                           7.444445
# 1                                           8.666667
# 2                                           5.083334
#
#    wind_dir_avg (wind_from_direction|degree|Wind From Direction)  \
# 0                                              321.0
# 1                                              341.0
# 2                                              269.0
#
#    air_temp_min (air_temperature|degree_C|Air Temperature (min))  \
# 0                                                4.9
# 1                                                4.0
# 2                                                3.3
#
#    air_temp_max (air_temperature|degree_C|Air Temperature (max))
# 0                                                6.0
# 1                                                4.9
# 2                                                3.9
# ../station-data/2022_fiona/sma_negl_rigolet_nlqu0002.csv
#    Unnamed: 0 time (time|UTC|Timestamp)  \
# 0           0      2022-09-20T00:52:00Z
# 1           1      2022-09-20T01:52:00Z
# 2           2      2022-09-20T02:52:00Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                    54.17608
# 1                                    54.17608
# 2                                    54.17608
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                     -58.43936
# 1                                     -58.43936
# 2                                     -58.43936
#
#    wind_spd_avg (wind_speed|m s-1|Wind Speed)  \
# 0                                    2.083333
# 1                                    0.861111
# 2                                    3.166667
#
#    air_temp_avg (air_temperature|degree_C|Air Temperature)  \
# 0                                                6.5
# 1                                                6.9
# 2                                                6.0
#
#    rel_humidity_max (relative_humidity|1|Relative Humidity (max))  \
# 0                                               64.0
# 1                                               63.0
# 2                                               70.0
#
#    wind_spd_max_dir (wind_from_direction|degree|Wind From Direction)  \
# 0                                              240.0
# 1                                              236.0
# 2                                              293.0
#
#    air_pressure_avg (air_pressure|mbar|Air Pressure)  \
# 0                                             1005.6
# 1                                             1006.0
# 2                                             1005.8
#
#    rel_humidity (relative_humidity|1|Relative Humidity)  \
# 0                                               62.0
# 1                                               61.0
# 2                                               70.0
#
#    rel_humidity_min (relative_humidity|1|Relative Humidity (min))  \
# 0                                               59.0
# 1                                               60.0
# 2                                               61.0
#
#    wind_spd_max (wind_speed_of_gust|m s-1|Wind Speed Of Gust)  \
# 0                                           2.722222
# 1                                           3.277778
# 2                                           4.250000
#
#    wind_dir_avg (wind_from_direction|degree|Wind From Direction)  \
# 0                                              246.0
# 1                                              264.0
# 2                                              272.0
#
#    air_temp_min (air_temperature|degree_C|Air Temperature (min))  \
# 0                                                5.9
# 1                                                6.5
# 2                                                6.0
#
#    air_temp_max (air_temperature|degree_C|Air Temperature (max))
# 0                                                6.8
# 1                                                6.9
# 2                                                7.0
# ../station-data/2022_fiona/SMA_red_island_shoal.csv
#    Unnamed: 0 time (time|UTC|Timestamp)  \
# 0           0      2022-09-20T03:50:00Z
# 1           1      2022-09-20T07:50:00Z
# 2           2      2022-09-20T11:50:00Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                   47.318377
# 1                                   47.318377
# 2                                   47.318377
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                    -54.122208
# 1                                    -54.122208
# 2                                    -54.122208
#
#    wind_spd_avg (wind_speed|m s-1|Wind Spd Avg)  \
# 0                                           1.3
# 1                                           2.4
# 2                                           5.9
#
#    air_temp_avg (air_temperature|degree_C|Air Temp Avg)  \
# 0                                               13.2
# 1                                               11.8
# 2                                               12.2
#
#    wind_dir2_avg (wind_from_direction|degree|Wind From Direction 2)  \
# 0                                              321.0
# 1                                              104.0
# 2                                               67.0
#
#    air_pressure_avg (air_pressure|mbar|Air Pressure)  \
# 0                                             1014.5
# 1                                             1015.9
# 2                                             1017.1
#
#    wind_spd_max (wind_speed_of_gust|m s-1|Wind Spd Max)  \
# 0                                                2.6
# 1                                                3.0
# 2                                                7.3
#
#    air_humidity_avg (relative_humidity|1|Air Humidity Avg)  \
# 0                                               76.1
# 1                                               93.0
# 2                                               90.7
#
#    wave_period_max (sea_surface_wave_maximum_period|s|Sea Surface Wave Maximum Period)  \
# 0                                                8.0
# 1                                                7.1
# 2                                                7.4
#
#    wave_dir_avg (sea_surface_wave_from_direction|degree|Sea Surface Wave From Direction)  \
# 0                                              245.0
# 1                                              230.0
# 2                                              227.0
#
#    wind_spd2_avg (wind_speed|m s-1|Wind Spd Avg 2)  \
# 0                                              1.3
# 1                                              2.2
# 2                                              5.9
#
#    wind_spd2_max (wind_speed_of_gust|m s-1|Wind Spd Max 2)  \
# 0                                                2.6
# 1                                                2.9
# 2                                                7.3
#
#    wind_dir_avg (wind_from_direction|degree|Wind From Direction)  \
# 0                                              314.0
# 1                                               95.0
# 2                                               58.0
#
#    wave_ht_max (sea_surface_wave_maximum_height|m|Wave Ht Max)  \
# 0                                                1.6
# 1                                                1.8
# 2                                                1.4
#
#    surface_temp_avg (sea_surface_temperature|degree_C|Surface Temp Avg)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    wave_ht_sig (sea_surface_wave_significant_height|m|Wave Ht Sig)
# 0                                                1.0
# 1                                                0.9
# 2                                                0.8
# ../station-data/2022_fiona/DFO_Sutron_NHARB.csv
#    Unnamed: 0 time (time|UTC|Timestamp)  \
# 0           0      2022-09-20T00:09:00Z
# 1           1      2022-09-20T00:19:00Z
# 2           2      2022-09-20T00:29:00Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                    47.84626
# 1                                    47.84626
# 2                                    47.84626
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                     -54.09684
# 1                                     -54.09684
# 2                                     -54.09684
#
#    water_temperature (sea_surface_temperature|degree_C|Surface Temp Avg)
# 0                                              13.96
# 1                                              14.00
# 2                                              14.00
# ../station-data/2022_fiona/DFO_Sutron_KLUMI.csv
#    Unnamed: 0 time (time|UTC|Timestamp)  \
# 0           0      2022-09-20T00:04:00Z
# 1           1      2022-09-20T00:14:01Z
# 2           2      2022-09-20T00:24:01Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                    47.59359
# 1                                    47.59359
# 2                                    47.59359
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                     -54.27349
# 1                                     -54.27349
# 2                                     -54.27349
#
#    wind_spd_gust (wind_speed_of_gust|m s-1|Wind Speed Of Gust)  \
# 0                                               6.57
# 1                                               5.66
# 2                                               5.66
#
#    wind_spd_avg (wind_speed|m s-1|Wind Speed Avgerage)  \
# 0                                               6.23
# 1                                               4.94
# 2                                               5.23
#
#    wind_dir_avg (wind_from_direction|degree|Wind From Direction)
# 0                                               42.0
# 1                                               41.0
# 2                                               42.0
# ../station-data/2022_fiona/SMA_saint_john.csv
#    Unnamed: 0 time (time|UTC|Timestamp)  \
# 0           0      2022-09-20T00:23:01Z
# 1           1      2022-09-20T00:53:01Z
# 2           2      2022-09-20T01:23:01Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                   45.197167
# 1                                   45.197167
# 2                                   45.197167
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                    -66.113767
# 1                                    -66.113767
# 2                                    -66.113767
#
#    wind_spd_avg (wind_speed|m s-1|Wind Spd Avg)  \
# 0                                           2.6
# 1                                           2.1
# 2                                           2.2
#
#    air_temp_avg (air_temperature|degree_C|Air Temp Avg)  \
# 0                                               85.3
# 1                                               85.3
# 2                                               85.3
#
#    air_pressure_avg (air_pressure|mbar|Air Pressure)  \
# 0                                             1016.4
# 1                                             1016.5
# 2                                             1016.6
#
#    wind_spd_max (wind_speed_of_gust|m s-1|Wind Spd Max)  \
# 0                                                3.1
# 1                                                2.9
# 2                                                2.6
#
#    wave_period_max (sea_surface_wave_maximum_period|s|Sea Surface Wave Maximum Period)  \
# 0                                                6.1
# 1                                                6.7
# 2                                                6.7
#
#    wind_dir_avg (wind_from_direction|degree|Wind From Direction)  \
# 0                                                107
# 1                                                 76
# 2                                                 70
#
#    wave_ht_max (sea_surface_wave_maximum_height|m|Wave Ht Max)  \
# 0                                                0.4
# 1                                                0.4
# 2                                                0.3
#
#    surface_temp_avg (sea_surface_temperature|degree_C|Surface Temp Avg)  \
# 0                                               14.5
# 1                                               14.6
# 2                                               14.8
#
#    wave_ht_sig (sea_surface_wave_significant_height|m|Wave Ht Sig)
# 0                                                0.3
# 1                                                0.2
# 2                                                0.2
# ../station-data/2022_fiona/SMA_st_johns.csv
#    Unnamed: 0 time (time|UTC|Timestamp)  \
# 0           0      2022-09-20T00:00:01Z
# 1           1      2022-09-20T00:30:01Z
# 2           2      2022-09-20T01:00:01Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                    47.56716
# 1                                    47.56716
# 2                                    47.56716
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                    -52.630578
# 1                                    -52.630578
# 2                                    -52.630578
#
#    wind_spd_avg (wind_speed|m s-1|Wind Speed Average)  \
# 0                                                3.9
# 1                                                3.6
# 2                                                2.1
#
#    air_temp_avg (air_temperature|degree_C|Air Temp Avg)  \
# 0                                               11.8
# 1                                               11.3
# 2                                               11.0
#
#    wind_dir2_avg (wind_from_direction|degree|Wind From Direction 2)  \
# 0                                                 58
# 1                                                 43
# 2                                                 75
#
#    air_pressure_avg (air_pressure|mbar|Air Pressure)  \
# 0                                             1014.7
# 1                                             1015.1
# 2                                             1015.3
#
#    wind_spd_max (wind_speed_of_gust|m s-1|Wind Speed Max)  \
# 0                                                5.1
# 1                                                4.8
# 2                                                3.0
#
#    air_humidity_avg (relative_humidity|1|Air Humidity Avg)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    wave_period_max (sea_surface_wave_maximum_period|s|Sea Surface Wave Maximum Period)  \
# 0                                               12.5
# 1                                               11.1
# 2                                                9.5
#
#    wave_dir_avg (sea_surface_wave_from_direction|degree|Sea Surface Wave From Direction)  \
# 0                                                 34
# 1                                                 34
# 2                                                 38
#
#    wind_spd2_max (wind_speed_of_gust|m s-1|Wind Speed Max 2)  \
# 0                                                4.7
# 1                                                4.2
# 2                                                2.8
#
#    wind_dir_avg (wind_from_direction|degree|Wind From Direction)  \
# 0                                                 43
# 1                                                 28
# 2                                                 60
#
#    wave_ht_max (sea_surface_wave_maximum_height|m|Wave Ht Max)  \
# 0                                                2.3
# 1                                                2.5
# 2                                                2.2
#
#    surface_temp_avg (sea_surface_temperature|degree_C|Surface Temp Avg)  \
# 0                                               13.3
# 1                                               13.2
# 2                                               13.2
#
#    wave_ht_sig (sea_surface_wave_significant_height|m|Wave Ht Sig)
# 0                                                1.4
# 1                                                1.4
# 2                                                1.3
# ../station-data/2022_fiona/candhis_spm_97501_timeseries.csv
#    Unnamed: 0 time (time|UTC|Timestamp)  \
# 0           0      2022-09-20T00:00:00Z
# 1           1      2022-09-20T00:30:00Z
# 2           2      2022-09-20T01:00:00Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                        46.7
# 1                                        46.7
# 2                                        46.7
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                      -56.1833
# 1                                      -56.1833
# 2                                      -56.1833
#
#    sea_surface_temp_avg (sea_surface_temperature|degree_C|Sea Surface Temp Avg)  \
# 0                                               13.9
# 1                                               13.9
# 2                                               13.8
#
#    wave_ht_sig_Hm0 (sea_surface_wave_significant_height|m|Wave Ht Sig Hm0)  \
# 0                                                1.2
# 1                                                1.2
# 2                                                1.2
#
#    wave_ht_max (sea_surface_wave_maximum_height|m|Wave Ht Max)  \
# 0                                                2.1
# 1                                                1.8
# 2                                                1.6
#
#    wave_ht_sig (sea_surface_wave_significant_height|m|Wave Ht Sig)
# 0                                                1.1
# 1                                                1.1
# 2                                                1.0
# ../station-data/2022_fiona/candhis_spm_97501_wave_spectra.csv
#    Unnamed: 0 time (time|UTC|Timestamp)  \
# 0           0      2022-09-20T00:00:00Z
# 1           1      2022-09-20T00:00:00Z
# 2           2      2022-09-20T00:00:00Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                        46.7
# 1                                        46.7
# 2                                        46.7
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                      -56.1833
# 1                                      -56.1833
# 2                                      -56.1833
#
#    direction (sea_surface_wave_from_direction|degree|Direction)
# 0                                                246
# 1                                                274
# 2                                                264
# ../station-data/2022_fiona/SPOT-1431_202204.csv
#    Unnamed: 0  time (time|UTC|Time)  \
# 0           0  2022-09-20T00:01:36Z
# 1           1  2022-09-20T00:31:36Z
# 2           2  2022-09-20T01:01:36Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                    43.89768
# 1                                    43.89775
# 2                                    43.89775
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                     -60.03570
# 1                                     -60.03572
# 2                                     -60.03572
#
#    wave_mean_period (sea_surface_wave_mean_period|seconds|mean period of the waves during sample time)  \
# 0                                               6.02
# 1                                               6.20
# 2                                               6.40
#
#    wave_significant_height (sea_surface_wave_significant_height|meters|wave height of the largest 1/3 of waves measured)  \
# 0                                               0.71
# 1                                               0.69
# 2                                               0.74
#
#    wind_speed (wind_speed|m/s|calculated wind speed from onboard sensor data)  \
# 0                                                1.6
# 1                                                1.6
# 2                                                1.6
#
#    surface_temp (sea_surface_temperature|degree_C|temperature on the ocean surface of buoy location)
# 0                                                NaN
# 1                                              16.04
# 2                                                NaN
# ../station-data/2022_fiona/SPOT-1461_202204.csv
#    Unnamed: 0  time (time|UTC|Time)  \
# 0           0  2022-09-20T00:27:32Z
# 1           1  2022-09-20T00:55:50Z
# 2           2  2022-09-20T01:25:50Z
#
#    latitude (latitude|degrees_north|Latitude)  \
# 0                                    43.89830
# 1                                    43.89832
# 2                                    43.89832
#
#    longitude (longitude|degrees_east|Longitude)  \
# 0                                     -60.08857
# 1                                     -60.08858
# 2                                     -60.08857
#
#    wave_mean_period (sea_surface_wave_mean_period|seconds|mean period of the waves during sample time)  \
# 0                                               6.04
# 1                                               6.36
# 2                                               6.50
#
#    wave_significant_height (sea_surface_wave_significant_height|meters|wave height of the largest 1/3 of waves measured)  \
# 0                                               0.69
# 1                                               0.72
# 2                                               0.75
#
#    wind_speed (wind_speed|m/s|calculated wind speed from onboard sensor data)  \
# 0                                                2.0
# 1                                                1.6
# 2                                                1.2
#
#    surface_temp (sea_surface_temperature|degree_C|temperature on the ocean surface of buoy location)
# 0                                              16.16
# 1                                                NaN
# 2                                              16.14
