# %%
# Using the watchdog library with filehandler
import sys
import os
import time
import logging
from logging.handlers import RotatingFileHandler
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler
import generate_bounds as gb
import time
import load_into_postgis as lpg

logging.basicConfig(
        handlers=[RotatingFileHandler('./file_watcher_log.log', maxBytes=100000, backupCount=10)],
        level=logging.DEBUG,
        format="[%(asctime)s] %(levelname)s [%(name)s.%(funcName)s:%(lineno)d] %(message)s",
        datefmt='%Y-%m-%dT%H:%M:%S')

logger= logging.getLogger(__name__)

def on_created(event):
    # This occurs when a new file has been added or created
    logger.info(
            "[{}] noticed: [{}] on: [{}] ".format(
                time.asctime(), event.event_type, event.src_path
            )
        )
    # It searches for the error cone shape file and converts it to a raw string
    # It is then used to get the boundary points by passing the path to the ts module
    # Gave a time sleep to give some time for all files to load
    sub_string = ".err.shp"
    
    if sub_string in event.src_path:
        logger.info("Shape File Detected!")
        time.sleep(10)
        path= r'{}'.format(event.src_path)  
        (min_long, min_lat, max_long, max_lat)= gb.get_boundary(ecc_shp_path=path)
        logger.info(min_long, min_lat, max_long, max_lat)
        return (min_long, min_lat, max_long, max_lat)
        #TODO This bounds can be connected to Jared scripts (need to figure out how)
    else:
        logger.info("Carry On!")

def on_deleted(event):
    logger.info(
            "[{}] noticed: [{}] on: [{}] ".format(
                time.asctime(), event.event_type, (event.src_path)
            )
        )
    logger.debug(event.src_path)

def on_modified(event):
    logger.info(
            "[{}] noticed: [{}] on: [{}] ".format(
                time.asctime(), event.event_type, event.src_path
            )
        )
    logger.debug(event.src_path)

def on_moved(event):
    logger.info(
            "[{}] noticed: [{}] on: [{}] ".format(
                time.asctime(), event.event_type, event.src_path
            )
        )
    logger.debug(event.src_path)

if __name__ == "__main__":
    
    
    event_handler = FileSystemEventHandler()
    #calling functions
    event_handler.on_created= on_created
    event_handler.on_deleted= on_deleted
    event_handler.on_modified= on_modified
    event_handler.on_moved= on_moved

    #set to watch the shapefiles directory
    path = os.path.abspath(os.path.join('..', 'shapefiles'))  
    
    observer = Observer()
    observer.schedule(event_handler, path, recursive=True) #recursive means it is monitoring everything in the sub folders so it should be left at True
    observer.start()
    try:
        logger.info ("Now Monitoring")
        while True:
            time.sleep(30)
            
    except KeyboardInterrupt:
        observer.stop()
        logger.info("Monitoring Interrupted")
    observer.join()
# Out:
# Now Monitoring
# [Thu Sep 14 16:21:07 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample
# [Thu Sep 14 17:23:44 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample
# [Thu Sep 14 18:26:25 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample
# [Thu Sep 14 19:29:03 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample
# [Thu Sep 14 20:31:44 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample
# [Thu Sep 14 21:34:25 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample
# [Thu Sep 14 21:41:24 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample\20220921_1200Z_FIONA.err.shp]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample\20220921_1200Z_FIONA.err.shp
# [Thu Sep 14 21:41:24 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\atlantic_canada_boundary.qmd]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\atlantic_canada_boundary.qmd
# [Thu Sep 14 21:41:24 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\atlantic_canada_boundary.shp]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\atlantic_canada_boundary.shp
# [Thu Sep 14 21:41:24 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\atlantic_canada_boundary.shx]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\atlantic_canada_boundary.shx
# [Thu Sep 14 21:41:24 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\hurricane_response_boundary.cpg]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\hurricane_response_boundary.cpg
# [Thu Sep 14 21:41:24 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\hurricane_response_boundary.dbf]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\hurricane_response_boundary.dbf
# [Thu Sep 14 21:41:24 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\hurricane_response_boundary.prj]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\hurricane_response_boundary.prj
# [Thu Sep 14 21:41:24 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\hurricane_response_boundary.qmd]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\hurricane_response_boundary.qmd
# [Thu Sep 14 21:41:24 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\hurricane_response_boundary.shp]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\hurricane_response_boundary.shp
# [Thu Sep 14 21:41:24 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\hurricane_response_boundary.shx]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\hurricane_response_boundary.shx
# [Thu Sep 14 22:37:04 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample
# [Thu Sep 14 23:39:43 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample
# [Fri Sep 15 00:42:21 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample
# [Fri Sep 15 01:44:58 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample
# [Fri Sep 15 02:47:34 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample
# [Fri Sep 15 03:50:11 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample
# [Fri Sep 15 04:52:47 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample
# [Fri Sep 15 05:55:25 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample
# [Fri Sep 15 06:58:03 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample
# [Fri Sep 15 08:00:42 2023] noticed: [modified] on: [c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample]
# c:\Users\ceboigbe\Documents\GitHub\hurricane-dashboard\shapefiles\fiona err cone sample
# Monitoring Interrupted
